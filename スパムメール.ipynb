# %% [markdown]
# <a href="https://colab.research.google.com/github/koseki3104/spam_mail/blob/main/%E3%82%B9%E3%83%91%E3%83%A0%E3%83%A1%E3%83%BC%E3%83%AB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/MyDrive/SIGNATE/【2025.07】スパムメール')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import zipfile

with zipfile.ZipFile("train.zip") as z:
    # すべてのファイルのパスを出力
    file_list = z.namelist()
    for name in file_list:
        print(name)
# Out:
# train2/
# train2/train_0000.txt
# train2/train_0001.txt
# train2/train_0002.txt
# train2/train_0003.txt
# train2/train_0004.txt
# train2/train_0005.txt
# train2/train_0006.txt
# train2/train_0007.txt
# train2/train_0008.txt
# train2/train_0009.txt
# train2/train_0010.txt
# train2/train_0011.txt
# train2/train_0012.txt
# train2/train_0013.txt
# train2/train_0014.txt
# train2/train_0015.txt
# train2/train_0016.txt
# train2/train_0017.txt
# train2/train_0018.txt
# train2/train_0019.txt
# train2/train_0020.txt
# train2/train_0021.txt
# train2/train_0022.txt
# train2/train_0023.txt
# train2/train_0024.txt
# train2/train_0025.txt
# train2/train_0026.txt
# train2/train_0027.txt
# train2/train_0028.txt
# train2/train_0029.txt
# train2/train_0030.txt
# train2/train_0031.txt
# train2/train_0032.txt
# train2/train_0033.txt
# train2/train_0034.txt
# train2/train_0035.txt
# train2/train_0036.txt
# train2/train_0037.txt
# train2/train_0038.txt
# train2/train_0039.txt
# train2/train_0040.txt
# ...

# %%
with zipfile.ZipFile("test.zip") as z:
    # すべてのファイルのパスを出力
    file_list = z.namelist()
    for name in file_list:
        print(name)
# Out:
# test2/
# test2/test_0000.txt
# test2/test_0001.txt
# test2/test_0002.txt
# test2/test_0003.txt
# test2/test_0004.txt
# test2/test_0005.txt
# test2/test_0006.txt
# test2/test_0007.txt
# test2/test_0008.txt
# test2/test_0009.txt
# test2/test_0010.txt
# test2/test_0011.txt
# test2/test_0012.txt
# test2/test_0013.txt
# test2/test_0014.txt
# test2/test_0015.txt
# test2/test_0016.txt
# test2/test_0017.txt
# test2/test_0018.txt
# test2/test_0019.txt
# test2/test_0020.txt
# test2/test_0021.txt
# test2/test_0022.txt
# test2/test_0023.txt
# test2/test_0024.txt
# test2/test_0025.txt
# test2/test_0026.txt
# test2/test_0027.txt
# test2/test_0028.txt
# test2/test_0029.txt
# test2/test_0030.txt
# test2/test_0031.txt
# test2/test_0032.txt
# test2/test_0033.txt
# test2/test_0034.txt
# test2/test_0035.txt
# test2/test_0036.txt
# test2/test_0037.txt
# test2/test_0038.txt
# test2/test_0039.txt
# test2/test_0040.txt
# test2/test_0041.txt
# test2/test_0042.txt
# test2/test_0043.txt
# test2/test_0044.txt
# ...
